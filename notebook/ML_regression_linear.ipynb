# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import sys
sys.path.append('../')

# %%
dataset = pd.read_csv('../data/StudentsPerformance.csv', sep=',')

# %%
dataset.shape
# Out:
# (1000, 8)

# %%
dataset.head()
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
# 2  female        group B  ...            95            93
# 3    male        group A  ...            57            44
# 4    male        group C  ...            78            75
#
# [5 rows x 8 columns]

# %%
dataset.rename(columns={'gender': 'genero', 'race/ethnicity': 'raca/etinia',
                'parenteral leval of education': 'nivel_escolar_familiar',
                'lunch': 'almoco',
                'test preparation course': 'curso_preparatorio',
                'math score' : 'nota_matematica',
                'reading score' : 'nota_leitura',
                'writing score' : 'nota_escrita' })
# Out:
#      genero raca/etinia  ... nota_leitura nota_escrita
# 0    female     group B  ...           72           74
# 1    female     group C  ...           90           88
# 2    female     group B  ...           95           93
# 3      male     group A  ...           57           44
# 4      male     group C  ...           78           75
# ..      ...         ...  ...          ...          ...
# 995  female     group E  ...           99           95
# 996    male     group C  ...           55           55
# 997  female     group C  ...           71           65
# 998  female     group D  ...           78           77
# 999  female     group D  ...           86           86
#
# [1000 rows x 8 columns]

# %%
X = dataset.iloc[:, [7]].values
y = dataset.iloc[:, 6].values

# %%
#formato de matriz com uma coluna a mais
X = X.reshape(-1, 1)

# %%
modelo = LinearRegression()
modelo.fit(X, y)
#R^2pode 
modelo.score(X, y)
# Out:
# 0.9112574888913137

# %%
#Interceptação
modelo.intercept_
# Out:
# np.float64(6.750504735875737)

# %%
modelo.coef_
# Out:
# array([0.91719069])

# %%
#score R^2
modelo.score(X, y)
# Out:
# 0.9112574888913137

# %%
previsoes = modelo.predict(X)
previsoes
# Out:
# array([74.62261585, 87.46328552, 92.04923897, 47.10689513, 75.53980654,
#        78.29137861, 91.13204828, 42.52094167, 68.20228101, 52.61003927,
#        54.44442065, 46.18970444, 73.70542516, 70.95385308, 59.9475648 ,
#        78.29137861, 85.62890414, 32.43184408, 48.94127651, 62.69913687,
#        64.53351825, 70.95385308, 55.36161134, 73.70542516, 80.12575999,
#        72.78823447, 57.19599272, 75.53980654, 66.36789963, 75.53980654,
#        74.62261585, 62.69913687, 66.36789963, 41.60375098, 81.96014137,
#        79.2085693 , 82.87733206, 60.86475549, 87.46328552, 59.03037411,
#        56.27880203, 69.1194717 , 66.36789963, 67.28509032, 56.27880203,
#        59.03037411, 63.61632756, 76.45699723, 76.45699723, 81.96014137,
#        50.77565789, 69.1194717 , 45.27251374, 75.53980654, 86.54609483,
#        46.18970444, 85.62890414, 51.69284858, 59.9475648 , 15.92241164,
#        72.78823447, 37.93498822, 57.19599272, 71.87104377, 60.86475549,
# ...

# %%
plt.scatter(X, y)
plt.plot(X, previsoes, color = 'red')
